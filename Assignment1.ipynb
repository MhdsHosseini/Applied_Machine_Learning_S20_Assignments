# %% [markdown]
# Assignment Set 1 by [Mahdis_Hosseini](https://github.com/MhdsHosseini) for Applied Machine Learning (Spring 2020) Course at Data Science Center, SBU

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j    

print("\n-> Execution Time = %s in Seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0 -0.408163  1.206287  0.297379  1.236727
# 1 -0.816437 -0.203026  0.429912  0.621097
# 2  0.694529 -1.007491 -0.306161  0.193243
# 3  0.857063  0.164192 -0.082009 -0.643874
# 4 -0.307933  0.849911  0.747252  2.151687
# 5 -0.074280 -0.903721  1.213019  0.451117
# 6 -0.333620  0.232818 -0.547551  0.698147
# 7 -0.385286  1.249735  1.557693  1.857464
# 8 -1.969771  0.235347  0.071890 -1.533366
# 9  0.382174  0.752425 -1.354179 -1.022386
#
# -> Execution Time = 18.409563541412354 in Seconds <-
